# %%
# %matplotlib ipympl
from proj_utils import InteractiveOscProbPlot
import matplotlib.pyplot as plt
import numpy as np

osc_params = {
  "experimental_baseline_km": 1300,
  "s12sq": 0.31,
  "s13sq": 0.02,
  "s23sq": 0.55,
  "delta": 0.7 * np.pi,
  "Dmsq21": 7.5e-5,
  "Dmsq31": 2.5e-3
}

# As the oscillation probability goes like sin(x/Energy)
#   Can get a smooth plot by distributing test points 
#   logarithmically and interpolating. The below generates 100
#   points between 10^-0.3 ~= 0.5 GeV and 10^0.75 ~= 5.6 GeV
Es = np.logspace(-0.3,0.75,100)
fig = InteractiveOscProbPlot(Es, osc_params)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
