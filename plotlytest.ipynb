# %%
import proj_utils as pu

# %%
DUNE_baseline = 1300 # km
pu.ipo.numu_survival_prob(ERange_GeV=[0.25,8], L_km=DUNE_baseline)
# Out:
# ...
#     'data': [{'mode': 'lines',
#               'name': 'Survival Probability',
#    …
