# %% [markdown]
# # Glossary
#
# ## Acronyms
#
# - **HEP:** High Energy Physics
# - **MC:** [Monte Carlo](#term_mc)
#
# ## Terms
#
# - <a id='term_mc'/> **Monte Carlo:** Shorthand for 'simulated experiment', named after the city famous for it's casinos because simulations make heavy use of random number generation (rolling the die).
