# %% [markdown]
# ### $\Gamma$.2.1: Gaussian Fitting
#
# Below you can interactively vary the _location_ and _scale_ parameters of a Gaussian to try and best describe a distribution of measurements.
#
# You can draw a new sample of measurements from a randomly chosen Gaussian distribution by clicking **Draw New Sample**. Each new sample comes
# from a new underlying true distribution. You can reveal the true Gaussian parameters that were used for the sample by clicking **Reveal Parameters**.
#
# How well are you able to guess the true _location_ and _scale_ parameters? How does the number of samples, $N$, affect your confidence in your chosen _most likely_ parameters?

# %%
# %matplotlib ipympl
from proj_utils import InteractiveGausFit

InteractiveGausFit()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...
# Button(button_style='info', description='Draw New Sample', icon='dice-d20', style=ButtonStyle())
# Button(button_style='info', description='Reveal Parameters', icon='display', style=ButtonStyle())
