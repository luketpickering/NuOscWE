# %% [markdown]
# # 2: Neutrino Oscillations
#
# The detailed derivation of the neutrino oscillation probability is involved, but we will discuss an approximate result that you can use to build intuition and then we will then use an interactive plot of the exact result to further develop intuition over the effects of oscillations.

# %% [markdown]
# ## 2.1 Neutrino States
#
# <img align="right" style="height:30em;margin-left:5em;" src="nbdata/numassflav.png" />
#
# The key starting point is that the three neutrinos that we know of do not, in fact, have a single set of identities. We have three _flavor_ states: $\nu_\mathrm{e}$, $\nu_\mu$, and $\nu_\tau$, which are the identities used for weak force interactions that also involve a charged lepton: electron, muon, or tau. We _also_ have three _mass_ states: $\nu_1$, $\nu_2$, $\nu_3$, these identities have well defined masses and are used when calculating how neutrinos travel through space. If we have a neutrino in a well defined _flavor_ state, then it must be in a _superposition_ of _mass_ states, and _vice versa_. As an example, if we consider a radioactive beta decay, which produces an electron and a neutrino, then we know that the neutrino must be in a $\nu_\mathrm{e}$ state as it was produced in an interaction involving an electron. As that neutrino travels from it's point of creation, it does so as a probabilistic combination of all three mass states. This might not make a lot of intuitive sense, many of the intermediate steps involved in quantum mechanics don't, but the observable predictions of quantum mechanics are increadibly precise, so even if you just consider it a mathematical tool, it is a very useful one.
#
# The figure on the right (reproduced from De Gouvêa: https://arxiv.org/pdf/hep-ph/0411274) provides an illustration for this dual nature of neutrinos: The three horizontal bands correspond to the three masses, which we know must differ as the difference between them is what drives oscillation. However, each mass corresponds to some proportion of each of the three flavors, represented by the fraction of each band that is colored. This figure graphically illustrates most of the parameters in neutrino oscillation: the two mass differences and the three different proportions that the three flavors can make up of the three masses. The one parameter that isn't illustrated is actually our parameter of interest, which we will introduce shortly.
#
# ## 2.2 Approximate Oscillation Probabilities
#
# For our purposes, we need to know the probability for a muon neutrino of energy, $E$ to interact and produce a charged lepton of flavor, $x$, after having travelled a distance, $L$. For the experiment we are discussing, $\nu_\tau$ are rarely visible and will not be used for the main measurement. So, what we really need to know is just the probabilities for a muon (anti)neutrino to be later detected as a muon (anti)neutrino or as an electron (anti)neutrino, called the muon neutrino survival, $P_{\nu_\mu\left(\bar{\nu}_\mu\right)\rightarrow\nu_\mu\left(\bar{\nu}_\mu\right)}$, and electron neutrino appearance, $P_{\nu_\mu\left(\bar{\nu}_\mu\right)\rightarrow\nu_\mathrm{e}\left(\bar{\nu}_\mathrm{e}\right)}$, probabilities, respectively. An approxmiate result can be taken as
#
# $$
# \def\thot{{{\color{red}\theta_{13}}}}
# \def\thtt{{{\color{blue}\theta_{23}}}}
# \def\dmto{{{\color{orange}\Delta{}m^2_{31}}}}
# \def\dmtwo{{{\color{cyan}\Delta{}m^2_{21}}}}
# \def\dmtt{{{\color{purple}\Delta{}m^2_{32}}}}
# \def\dcp{{{\color{green}\delta_\mathrm{CP}}}}
# \require{ams}
# $$
#
# $$
# \begin{align*}
# P_{\nu_\mu\left(\bar{\nu}_\mu\right)\rightarrow\nu_\mu\left(\bar{\nu}_\mu\right)}\left(L,E\right) & \simeq 1 - 4\cos^2\thot\sin^2\thtt\left[1 - \cos^2\thot\sin^2\thtt\right]\sin^2\frac{\dmtt{}L}{4E} \\
# & + \left[\mathrm{higher\ order\ terms}\right], \\
# &\\
# P_{\nu_\mu\left(\bar{\nu}_\mu\right)\rightarrow\nu_\mathrm{e}\left(\bar{\nu}_\mathrm{e}\right)} \left(L,E\right) & \simeq \sin^2\thtt\sin^22\thot\sin^2\frac{\dmto{}L}{4E} \\
# & + \sin^22\thtt\sin^22\thot\cos\thot\sin\frac{\dmtwo{}L}{4E}\sin\frac{\dmto{}L}{4E} \\
# & \times \left[\cos\frac{\dmtt{}L}{4E}\cos\dcp -\left(+\right) \sin\frac{\dmtt{}L}{4E}\sin\dcp\right] \\
# & +  \left[\mathrm{higher\ order\ terms}\right],
# \end{align*}
# $$
#
# where $\theta_{ij}$ are called the mixing angles and control the proportion of each flavor state within each mass state, $\Delta{}m^{2}_{ij} = m^2_i - m^2_j$ are the mass-squared splittings between the masses of the three mass states, and $\delta_{CP}$ is the Charge-Parity violating phase factor, our parameter of most interest. The equations above are long, complex, and approximate, you should not expect to build general intuition from staring at them. There are two important points to take away. The first is that they are built of trignometric functions of the propagation distance, $L$ over the neutrino Energy, $E$, which gives the probabilities a characteristic _oscillatory_ behavior as a function of either $L$ or $E$, as shown below:
#
#
# The second important point is that the only difference between the predicted oscillations of neutrinos and antineutrinos is the bracketed sign, $-\left(+\right)$ at the end of electron (anti)neutrino appearance probability. This term can generate a difference between the oscillations of neutrinos and antineutrinos if it is nonzero, which is true if and only if $\sin\delta_\mathrm{CP} \neq 0$.

# %% [markdown]
# ## 2.X Interactive Oscillations Calculator
#
# Run the cell below (shift + enter) to start an interactive plot that will let you explore the predicted probability for a muon (anti)neutrino of energy, E, to oscillate to a muon (anti)neutrino or an electron (anti)neutrino after travelling a distance, L.
#
# The top two plots show the probability of the oscillation, the left hand side shows the muon neutrino _survival_ probability and the right hand side shows the electron neutrino _appearance_ probability. **N.B.** the different y axis scale on the left and right plots; the maximum electron neutrino _appearance_ probability never approaches 1. The transparent regions show the muon (anti) neutrino energy distribution before any oscillation has taken place.
#
# The bottom two plots show the relative number of interacting muon and electron (anti)neutrinos that an experiment might see from a muon neutrino beam on the left, and a muon antineutrino beam on the right. The transparent curves that do not respond to changing the parameter sliders are the predictions for the default parameter values to give you a visual reference for the effect of changing each parameter value.
#
# Some questions to try and answer:
# - Do you think we can measure the $\mathrm{sin}^{2}(\theta_{12})$ parameter with the T2K, NOvA, or DUNE experiments? Why or why not?
# - Which parameters do you think we might be able to measure with experiments such as these?
# - Do you think we might learn more about some parameters from the _surviving_ muon (anti)neutrinos? What about the _appearing_ electron (anti)neutrinos?
# - Do any parameters produce similar changes in one observable distribution or another?
#   + Do you think this makes those parameters easier or harder to measure? Why?
# - Why do you think the energies and baselines of these experiments were chosen as they are?
#   + If you change the peak energy a bit, can we learn more or less about specific parameters?
# - If we specifically want to learn about the $\delta_\mathrm{CP}$ parameter, do the values of the other parameters matter at all?
#
# _Hint:_ If the controls become unresponsive, just re-run the cell. Interactive plots can be quite fragile. Try to click on values rather than drag the sliders...

# %%
# %matplotlib widget

from proj_utils import InteractiveOscProbPlot
import numpy as np

DUNE_baseline = 1300 # km
DUNE_energy_distribution = { "peak": 2.2, "width": 1.1, "range": (0.1, 8) } # GeV

NOvA_baseline = 810 # km
NOvA_energy_distribution = { "peak": 1.9, "width": 0.6 } # GeV

T2K_baseline = 295 # km
T2K_energy_distribution = { "peak": 0.6, "width": 0.2 } # GeV

osc_params = {
  "experimental_energy_distribution": DUNE_energy_distribution,
  "experimental_baseline_km": DUNE_baseline,
  "s12sq": 0.31,
  "s13sq": 0.02,
  "s23sq": 0.47,
  "delta": 0.7 * np.pi,
  "Dmsq21": 7.5e-5,
  "Dmsq31": 2.5e-3
}

InteractiveOscProbPlot(osc_params)
