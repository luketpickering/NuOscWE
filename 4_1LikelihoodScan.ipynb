# %% [markdown]
# ### $\Gamma$.3.1.1: Interactive Likelihood Scan

# %%
# %matplotlib ipympl
from proj_utils import InteractiveLikelihoodScan

InteractiveLikelihoodScan()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# HBox(children=(Label(value='$\\Delta\\mathrm{m}_{31}^{2}$ [$10^{-3}$ eV]'), FloatSlider(value=2.65, max=2.7, m…
