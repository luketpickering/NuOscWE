# %% [markdown]
# ### $\Gamma$.3.1.1: Interactive Likelihood Scan

# %%
# %matplotlib ipympl
from proj_utils import InteractiveLikelihoodScan_2

InteractiveLikelihoodScan_2()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...
# Button(button_style='info', description='Calculate Delta Chi2', icon='calculator', style=ButtonStyle())
# Button(button_style='info', description='Run the Experiment', icon='person-running', style=ButtonStyle())
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
