# %% [markdown]
# ### $\Gamma$.3.1.1: Interactive Likelihood Scan

# %%
# %matplotlib ipympl
from proj_utils import InteractiveLikelihoodScan

InteractiveLikelihoodScan()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
