# %% [markdown]
# # Project Lab Script
#
# * 1. Introductory Slides
# * 2. [Oscillation Probability Playground](./2OscillationProbabilityPlayground.ipynb)
# * C [Event Sample Selection](./3EventSamples.ipynb)
# * $\Gamma$ [Model-based Inference and Parametric Fitting](./4ModelFitting.ipynb)
# * 4. [Measuring the Difference between Oscillations of Neutrinos and Antineutrinos](./5Analysis.ipynb)
#
# [Glossary of Acronyms and Terms](./6Glossary.ipynb)
